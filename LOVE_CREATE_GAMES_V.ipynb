# %%
import random

# Definición de personajes
characters = ["Maicol", "Gabriel", "Kevin", "Miguel"]

# Definición de la historia y el árbol de probabilidad de acontecimientos
story_tree = {
    "start": {
        "description": "Te encuentras en una encrucijada en el bosque. ¿Qué decides hacer?",
        "choices": {
            "Ir hacia el norte": {
                "description": "Te diriges hacia el norte y encuentras un río. ¿Qué haces?",
                "choices": {
                    "Cruzar el río": {
                        "description": "Cruzas el río y te encuentras con un oso. ¿Qué haces?",
                        "choices": {
                            "Huir": {
                                "description": "Huyes del oso y te pierdes en el bosque. ¿Qué haces?",
                                "choices": {
                                    "Buscar refugio": {
                                        "description": "Encuentras una cueva y te refugias. ¿Qué haces?",
                                        "choices": {
                                            "Explorar la cueva": {
                                                "description": "Exploras la cueva y encuentras un tesoro. ¡Felicidades, has ganado!",
                                                "choices": {}
                                            },
                                            "Esperar hasta el amanecer": {
                                                "description": "Esperas hasta el amanecer y encuentras el camino de regreso a casa. ¡Felicidades, has ganado!",
                                                "choices": {}
                                            }
                                        }
                                    },
                                    "Seguir corriendo": {
                                        "description": "Sigues corriendo y te encuentras con una tribu amigable. ¿Qué haces?",
                                        "choices": {
                                            "Unirte a la tribu": {
                                                "description": "Te unes a la tribu y vives felizmente con ellos. ¡Felicidades, has ganado!",
                                                "choices": {}
                                            },
                                            "Pedir ayuda para regresar a casa": {
                                                "description": "La tribu te ayuda a regresar a casa. ¡Felicidades, has ganado!",
                                                "choices": {}
                                            }
                                        }
                                    }
                                }
                            },
                            "Enfrentar al oso": {
                                "description": "Enfrentas al oso y logras ahuyentarlo. ¿Qué haces?",
                                "choices": {
                                    "Seguir explorando el bosque": {
                                        "description": "Sigues explorando el bosque y encuentras una cabaña abandonada. ¿Qué haces?",
                                        "choices": {
                                            "Entrar en la cabaña": {
                                                "description": "Entras en la cabaña y encuentras provisiones. ¡Felicidades, has ganado!",
                                                "choices": {}
                                            },
                                            "Seguir explorando el bosque": {
                                                "description": "Sigues explorando el bosque y encuentras el camino de regreso a casa. ¡Felicidades, has ganado!",
                                                "choices": {}
                                            }
                                        }
                                    },
                                    "Regresar al río": {
                                        "description": "Regresas al río y construyes una balsa para cruzarlo. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    }
                                }
                            }
                        }
                    },
                    "Seguir el río hacia el este": {
                        "description": "Sigues el río hacia el este y encuentras una cascada. ¿Qué haces?",
                        "choices": {
                            "Descansar junto a la cascada": {
                                "description": "Descansas junto a la cascada y recuperas energías. ¿Qué haces?",
                                "choices": {
                                    "Explorar los alrededores": {
                                        "description": "Exploras los alrededores y encuentras un sendero que te lleva a una aldea. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    },
                                    "Seguir descansando": {
                                        "description": "Sigues descansando y te encuentras con un viajero que te guía de regreso a casa. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    }
                                }
                            },
                            "Subir la cascada": {
                                "description": "Subes la cascada y encuentras una cueva secreta. ¿Qué haces?",
                                "choices": {
                                    "Entrar en la cueva": {
                                        "description": "Entras en la cueva y encuentras un mapa del tesoro. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    },
                                    "Seguir explorando": {
                                        "description": "Sigues explorando y encuentras el camino de regreso a casa. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    }
                                }
                            }
                        }
                    }
                }
            },
            "Ir hacia el sur": {
                "description": "Te diriges hacia el sur y encuentras un desierto. ¿Qué haces?",
                "choices": {
                    "Cruzar el desierto": {
                        "description": "Cruzas el desierto y encuentras una ciudad. ¿Qué haces?",
                        "choices": {
                            "Explorar la ciudad": {
                                "description": "Exploras la ciudad y encuentras un mercado. ¿Qué haces?",
                                "choices": {
                                    "Comprar provisiones": {
                                        "description": "Compras provisiones y encuentras un mapa del tesoro. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    },
                                    "Hablar con los lugareños": {
                                        "description": "Hablas con los lugareños y te ayudan a encontrar el camino de regreso a casa. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    }
                                }
                            },
                            "Seguir explorando el desierto": {
                                "description": "Sigues explorando el desierto y encuentras una caravana. ¿Qué haces?",
                                "choices": {
                                    "Unirte a la caravana": {
                                        "description": "Te unes a la caravana y viajas con ellos. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    },
                                    "Pedir ayuda para regresar a casa": {
                                        "description": "La caravana te ayuda a regresar a casa. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    }
                                }
                            }
                        }
                    },
                    "Buscar un oasis": {
                        "description": "Buscas un oasis y encuentras un manantial. ¿Qué haces?",
                        "choices": {
                            "Descansar junto al manantial": {
                                "description": "Descansas junto al manantial y recuperas energías. ¿Qué haces?",
                                "choices": {
                                    "Explorar los alrededores": {
                                        "description": "Exploras los alrededores y encuentras un sendero que te lleva a una aldea. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    },
                                    "Seguir descansando": {
                                        "description": "Sigues descansando y te encuentras con un viajero que te guía de regreso a casa. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    }
                                }
                            },
                            "Seguir explorando el desierto": {
                                "description": "Sigues explorando el desierto y encuentras una caravana. ¿Qué haces?",
                                "choices": {
                                    "Unirte a la caravana": {
                                        "description": "Te unes a la caravana y viajas con ellos. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    },
                                    "Pedir ayuda para regresar a casa": {
                                        "description": "La caravana te ayuda a regresar a casa. ¡Felicidades, has ganado!",
                                        "choices": {}
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }
    }
}

# Función para jugar la historia
def play_story(node):
    print(node["description"])
    if not node["choices"]:
        return
    choices = list(node["choices"].keys())
    for i, choice in enumerate(choices):
        print(f"{i + 1}. {choice}")
    choice = int(input("Elige una opción: ")) - 1
    play_story(node["choices"][choices[choice]])

# Iniciar la historia
play_story(story_tree["start"])
# Out:
# Te encuentras en una encrucijada en el bosque. ¿Qué decides hacer?
# 1. Ir hacia el norte
# 2. Ir hacia el sur
# Elige una opción: 2
# Te diriges hacia el sur y encuentras un desierto. ¿Qué haces?
# 1. Cruzar el desierto
# 2. Buscar un oasis
# Elige una opción: 2
# Buscas un oasis y encuentras un manantial. ¿Qué haces?
# 1. Descansar junto al manantial
# 2. Seguir explorando el desierto
# Elige una opción: 2
# Sigues explorando el desierto y encuentras una caravana. ¿Qué haces?
# 1. Unirte a la caravana
# 2. Pedir ayuda para regresar a casa
